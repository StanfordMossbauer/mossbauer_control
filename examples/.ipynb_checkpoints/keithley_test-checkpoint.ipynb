# %%
import pyvisa
import time
import matplotlib.pyplot as plt 
import numpy as np
import csv 
import os
from pyvisa.constants import ControlFlow, Parity, StopBits

# %%
rm = pyvisa.ResourceManager()
resource_string = "GPIB0::7::INSTR"
voltmeter = rm.open_resource(resource_string)

# %%
voltmeter.baud_rate = 19200
voltmeter.parity = pyvisa.constants.Parity.none
voltmeter.stop_bits = pyvisa.constants.StopBits.one
voltmeter.data_bits = 8
voltmeter.flow_control = ControlFlow.none

# %%
voltmeter.write(':SENS:VOLT:DC:NPLC 0.1')
voltmeter.write(':SENS:VOLT:DC:DFIL:STAT OFF')
# Out:
# 29

# %%
print(voltmeter.query('*IDN?'))
# Out:
# KEITHLEY INSTRUMENTS INC.,MODEL 2182A,4658571,C08/B01

# %%
voltmeter.write(":CONF:VOLT")
voltmeter.write('TRIG:DEL 0.5')
voltmeter.write(':SAMP:COUN 10')
voltmeter.write("CONF:VOLT")
data = voltmeter.write("MEAS?")
data = voltmeter.query("READ?")
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[12], line 6
#       4 voltmeter.write("CONF:VOLT")
#       5 data = voltmeter.write("MEAS?")
# ----> 6 data = voltmeter.query("READ?")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\resources\messagebased.py:690, in MessageBasedResource.query(self, message, delay)
#     687 if delay > 0.0:
#     688     time.sleep(delay)
# --> 690 return self.read()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\resources\messagebased.py:519, in MessageBasedResource.read(self, termination, encoding)
#     517 if termination is None:
#     518     termination = self._read_termination
# --> 519     message = self._read_raw().decode(enco)
#     520 else:
#     521     with self.read_termination_context(termination):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\resources\messagebased.py:473, in MessageBasedResource._read_raw(self, size, monitoring_interface)
#     466 while status == loop_status:
#     467     logger.debug(
#     468         "%s - reading %d bytes (last status %r)",
#     469         self._resource_name,
#     470         size,
#     471         status,
#     472     )
# --> 473     chunk, status = self.visalib.read(self.session, size)
#     474     if monitoring_interface:
#     475         monitoring_interface.update(len(chunk))
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\ctwrapper\functions.py:2339, in read(library, session, count)
#    2337 buffer = create_string_buffer(count)
#    2338 return_count = ViUInt32()
# -> 2339 ret = library.viRead(session, buffer, count, byref(return_count))
#    2340 return buffer.raw[: return_count.value], ret
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\ctwrapper\highlevel.py:227, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     224         # Set session back to a safe value
#     225         session = None
# --> 227 return self.handle_return_value(session, ret_value)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\highlevel.py:252, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     249     self._last_status_in_session[session] = rv
#     251 if rv < 0:
# --> 252     raise errors.VisaIOError(rv)
#     254 if rv in self.issue_warning_on:
#     255     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.

# %%
data
# Out:
# 7

# %%
data_list = []
time_array = []
timestamps = []
i = 1
while i<50:
    i+=1
    time.sleep(0.03)
    data = voltmeter.query("MEAS?")
    data_list.append(data)
    time_array.append(0.1*i)
    timestamps.append(time.time())

# %%
data_list
cleaned_data = [float(item.strip()) for item in data_list]

# %%
plt.plot(timestamps, cleaned_data, color = 'pink')

# %%
timestamps[3]-timestamps[2]
# Out:
# 1.4747288227081299

# %%
voltmeter.write(":TRAC:CLE")            
voltmeter.write(":TRAC:POIN 1000")       
voltmeter.write(":TRAC:FEED SENS")    
voltmeter.write(":INIT:CONT ON")      
voltmeter.write(":INIT")      

data_list = []
time_array = []
timestamps = []
start = time.time()
i = 1
while i<1000:
    i+=1
    time.sleep(1)
    data = voltmeter.query(":FETCH?")
    data_list.append(float(data))
    timestamps.append(time.time()-start)

# %%
#data_list, timestamps

# %%
plt.plot(timestamps, data_list, color = 'purple')

# %%
plt.plot(timestamps[:1000], data_list[:1000])

# %%
voltmeter.query(":OUTP:GAIN?")
#voltmeter.write("OUTP:GAIN 10")
# Out:
# '1.000000E+01\r\n'

# %%
osci.close()
