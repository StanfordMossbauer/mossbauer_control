# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\mossbauer\\Documents\\data\\0930\\all_closed2025-10-01.csv')

# %%
df
# Out:
#                time    data V       amp  theta
# 0      1.759302e+09 -0.003354 -0.546024    0.0
# 1      1.759302e+09 -0.003354 -0.546024    0.0
# 2      1.759302e+09 -0.003354 -0.546024    0.0
# 3      1.759302e+09 -0.003354 -0.546024    0.0
# 4      1.759302e+09 -0.003354 -0.546024    0.0
# ...             ...       ...       ...    ...
# 80613  1.759388e+09 -0.003361 -0.546024    0.0
# 80614  1.759388e+09 -0.003361 -0.546024    0.0
# 80615  1.759388e+09 -0.003361 -0.546024    0.0
# 80616  1.759388e+09 -0.003361 -0.546024    0.0
# 80617  1.759388e+09 -0.003361 -0.546024    0.0
#
# [80618 rows x 4 columns]

# %%
time = df["time"]-df["time"][0]
plt.scatter(time/(60*60), df["data V"])
