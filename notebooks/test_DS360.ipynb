# %%
import pyvisa
import time
import matplotlib.pyplot as plt 
import numpy as np
import csv 
import os
from pyvisa.constants import ControlFlow, Parity, StopBits
import pandas as pd

# %%
gpib_address = 8
rm = pyvisa.ResourceManager()
ds360 = rm.open_resource(f"GPIB::{gpib_address}", )
print(rm.list_opened_resources())
# Out:
# [<'GPIBInstrument'('GPIB0::8::INSTR')>]

# %%
#set to sine fct
ds360.write("FUNC 0") # 0 is for sine, 1 for square, ..
# Out:
# 8

# %%
ds360.write("FUNC 1")
# Out:
# 8

# %%
#set frequency
ds360.write("FREQ 41")
# Out:
# 9

# %%
ds360.write("FREQ 40")
# Out:
# 9

# %%
#set amplitude
ds360.write("AMPL0.3 VP")
# Out:
# 12

# %%
#set offset
ds360.write("OFFS 10")
# Out:
# 9

# %%
#enable output
ds360.write("OUTE 1")
#disable with 0
# Out:
# 8
