# %%
import pyvisa
import time
import matplotlib.pyplot as plt 
import numpy as np
import csv 
import os
from pyvisa.constants import ControlFlow, Parity, StopBits
import pandas as pd

# %%
#asrl3::instr "COM3" is the srsdc205

# %%
rm = pyvisa.ResourceManager()
dc205 = rm.open_resource("ASRL3::INSTR", )
print(rm.list_opened_resources())
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[24], line 2
#       1 rm = pyvisa.ResourceManager()
# ----> 2 dc205 = rm.open_resource("ASRL3::INSTR", )
#       3 print(rm.list_opened_resources())
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\highlevel.py:3293, in ResourceManager.open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    3287     if not present:
#    3288         raise ValueError(
#    3289             "%r is not a valid attribute for type %s"
#    3290             % (key, res.__class__.__name__)
#    3291         )
# -> 3293 res.open(access_mode, open_timeout)
#    3295 for key, value in kwargs.items():
#    3296     setattr(res, key, value)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\resources\resource.py:282, in Resource.open(self, access_mode, open_timeout)
#     278 logger.debug("%s - opening ...", self._resource_name, extra=self._logging_extra)
#     279 with self._resource_manager.ignore_warning(
#     280     constants.StatusCode.success_device_not_present
#     281 ):
# --> 282     self.session, status = self._resource_manager.open_bare_resource(
#     283         self._resource_name, access_mode, open_timeout
#     284     )
#     286     if status == constants.StatusCode.success_device_not_present:
#     287         # The device was not ready when we opened the session.
#     288         # Now it gets five seconds more to become ready.
#     289         # Every 0.1 seconds we probe it with viClear.
#     290         start_time = time.time()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\highlevel.py:3218, in ResourceManager.open_bare_resource(self, resource_name, access_mode, open_timeout)
#    3189 def open_bare_resource(
#    3190     self,
#    3191     resource_name: str,
#    3192     access_mode: constants.AccessModes = constants.AccessModes.no_lock,
#    3193     open_timeout: int = constants.VI_TMO_IMMEDIATE,
#    3194 ) -> Tuple[VISASession, StatusCode]:
#    3195     """Open the specified resource without wrapping into a class.
#    3196
#    3197     Parameters
#    (...)
#    3216
#    3217     """
# -> 3218     return self.visalib.open(self.session, resource_name, access_mode, open_timeout)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\ctwrapper\functions.py:1853, in open(library, session, resource_name, access_mode, open_timeout)
#    1849 out_session = ViSession()
#    1851 # [ViSession, ViRsrc, ViAccessMode, ViUInt32, ViPSession]
#    1852 # ViRsrc converts from (str, unicode, bytes) to bytes
# -> 1853 ret = library.viOpen(
#    1854     session, resource_name, access_mode, open_timeout, byref(out_session)
#    1855 )
#    1856 return out_session.value, ret
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\ctwrapper\highlevel.py:227, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     224         # Set session back to a safe value
#     225         session = None
# --> 227 return self.handle_return_value(session, ret_value)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\highlevel.py:252, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     249     self._last_status_in_session[session] = rv
#     251 if rv < 0:
# --> 252     raise errors.VisaIOError(rv)
#     254 if rv in self.issue_warning_on:
#     255     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_RSRC_BUSY (-1073807246): The resource is valid, but VISA cannot currently access it.

# %%
try:
    rm = pyvisa.ResourceManager()
    inst = rm.open_resource("GPIB0::14::INSTR")
    print(inst.query("*IDN?"))
finally:
    try:
        inst.close()
    except:
        pass
    try:
        rm.close()
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[25], line 4
#       2     rm = pyvisa.ResourceManager()
#       3     inst = rm.open_resource("GPIB0::14::INSTR")
# ----> 4     print(inst.query("*IDN?"))
#       5 finally:
#       6     try:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\resources\messagebased.py:684, in MessageBasedResource.query(self, message, delay)
#     667 def query(self, message: str, delay: Optional[float] = None) -> str:
#     668     """A combination of write(message) and read()
#     669
#     670     Parameters
#    (...)
#     682
#     683     """
# --> 684     self.write(message)
#     686     delay = self.query_delay if delay is None else delay
#     687     if delay > 0.0:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\resources\messagebased.py:213, in MessageBasedResource.write(self, message, termination, encoding)
#     207         warnings.warn(
#     208             "write message already ends with termination characters",
#     209             stacklevel=2,
#     210         )
#     211     message += term
# --> 213 count = self.write_raw(message.encode(enco))
#     215 return count
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\resources\messagebased.py:173, in MessageBasedResource.write_raw(self, message)
#     159 def write_raw(self, message: bytes) -> int:
#     160     """Write a byte message to the device.
#     161
#     162     Parameters
#    (...)
#     171
#     172     """
# --> 173     return self.visalib.write(self.session, message)[0]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\ctwrapper\functions.py:2798, in write(library, session, data)
#    2796 return_count = ViUInt32()
#    2797 # [ViSession, ViBuf, ViUInt32, ViPUInt32]
# -> 2798 ret = library.viWrite(session, data, len(data), byref(return_count))
#    2799 return return_count.value, ret
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\ctwrapper\highlevel.py:227, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     224         # Set session back to a safe value
#     225         session = None
# --> 227 return self.handle_return_value(session, ret_value)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pyvisa\highlevel.py:252, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     249     self._last_status_in_session[session] = rv
#     251 if rv < 0:
# --> 252     raise errors.VisaIOError(rv)
#     254 if rv in self.issue_warning_on:
#     255     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_NLISTENERS (-1073807265): No listeners condition is detected (both NRFD and NDAC are deasserted).

# %%
for resource in rm.list_opened_resources():
    try:
        resource.close()
        print(f"Closed: {resource.resource_name}")
    except Exception as e:
        print(f"Error closing resource: {e}")

# %%
dc205.query("*IDN?")
# Out:
# 'Stanford_Research_Systems,DC205,s/n20500803,ver1.80\r\n'

# %%
dc205.write("VOLT -2")
# Out:
# 9

# %%
dc205.write("SOUT ON")
# Out:
# 9

# %% [raw]
# dc205.write("SOUT ON")

# %%
#get the bnc box in the correct state
bnc.write_termination = '\r\n'
bnc.read_termination = '\r\n'
bnc.timeout = 5000

# %%
#check if termination works
bnc.query("*IDN?")
# Out:
# '555-2-000-01.00'

# %%
#always reset
bnc.write("*RST")
# Out:
# 6

# %%
#set it to be triggered by the 60Hz input from the DS360
bnc.write(":PULSE0:MODE BURST")
bnc.write(":PULSE0:EXT:MODE TRIG")
bnc.write(":PULSE0:EXT:EDGE RIS")
bnc.write(":PULSE0:EXT:LEV 1.0")
bnc.write(":PULSE0:STAT ON")
bnc.write(":PULSE0:PER 0.00032") #system period to 300Hz
bnc.write(":PULSE0:BCO 5") #define the max BCO for other channels also
# Out:
# 15

# %%
#300 Hz from 60Hz signal
bnc.write(":PULSE1:STAT ON")
bnc.write(":PULSE1:CMOD BURST")
bnc.write(":PULSE1:BCO 5") #changes number of pulses
bnc.write(":PULSE1:WIDT 0.0001")
bnc.write(":PULSE1:DEL 0")
# Out:
# 15

# %%
#DAQ signal 
bnc.write(":PULSE2:STAT ON")
bnc.write(":PULSE2:CMOD BURST")
bnc.write(":PULSE2:BCO 4") #changes number of pulses
bnc.write(":PULSE2:WIDT 0.0001")
bnc.write(":PULSE2:DEL 0.031")
# Out:
# 19

# %%
#DAQ at 0.1Hz for the other devices
bnc.write(":PULSE3:STAT ON")
bnc.write(":PULSE3:CMOD BURST")
bnc.write(":PULSE3:BCO 1") #changes number of pulses
bnc.write(":PULSE3:WIDT 0.0001")
bnc.write(":PULSE3:DEL 0")
# Out:
# 15

# %%
#pulses in general 
bnc.write(":PULSE2:CMOD BURST")
bnc.write(":PULSE2:BCO 2") #changes number of pulses
bnc.write(":PULSE2:WIDT 0.000625")
#bnc.write(":PULSE1:WIDT 0.0001")
bnc.write(":PULSE2:DEL 0")
bnc.write(":PULSE2:STAT ON")
# Out:
# 18

# %%
bnc.write(":PULSE2:STAT OFF")
bnc.write(":PULSE3:STAT OFF")
# Out:
# 18

# %%
#alternative: use 10Mhz external clock to synch BNC555 and DS360
#just generate pulses then from internal clock
bnc.write(":PULSE0:MODE CONT")
bnc.write(":PULSE0:PER 0.00001") #10kHz internal clock
bnc.write(":PULSE0:STAT ON")
# Out:
# 17

# %%
#now just use the internal clock to get the rest of the frequencies
#get 1kHz run trigger
bnc.write(":PULSE1:STAT ON")
bnc.write(":PULSE1:CMOD DIV")
bnc.write(":PULSE1:DCO 10")
bnc.write(":PULSE1:WIDT 0.00001")
bnc.write(":PULSE1:DEL 0")
# Out:
# 15

# %%
#get 800Hz DAQ trigger 
#it is 833Hz right now
bnc.write(":PULSE2:STAT ON")
bnc.write(":PULSE2:CMOD DIV")
bnc.write(":PULSE2:DCO 12")
bnc.write(":PULSE2:WIDT 0.00001")
bnc.write(":PULSE2:DEL 0")
# Out:
# 15

# %%
#get the 1Hz trigger
bnc.write(":PULSE3:STAT ON")
bnc.write(":PULSE3:CMOD DIV")
bnc.write(":PULSE3:DCO 10000")
bnc.write(":PULSE3:WIDT 0.00001")
bnc.write(":PULSE3:DEL 0")
# Out:
# 15

# %%
print(rm.list_opened_resources())
# Out:
# []

# %%
for resource in rm.list_opened_resources():
    try:
        resource.close()
        print(f"Closed: {resource.resource_name}")
    except Exception as e:
        print(f"Error closing resource: {e}")
# Out:
# Error closing resource: Invalid session handle. The resource might be closed.
# Error closing resource: Invalid session handle. The resource might be closed.
